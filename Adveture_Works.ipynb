# %%
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import datetime as dt

# %%
load_dotenv("coffee_db.env")
CONN= os.getenv('SQL_CONN')

# %%
try:
    engine = create_engine(CONN)
except Exception as e:
    print(e)

# %%
tables_query = "SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_TYPE = 'BASE TABLE'"

# %%
tables=pd.read_sql(tables_query,engine)['TABLE_NAME'].tolist()

# %%
tables
# Out:
# ['DimSalesTerritory',
#  'DimCustomer',
#  'DimDate',
#  'DimGeography',
#  'DimProduct',
#  'FactInternetSales']

# %%
DataFrame={}
for table in tables:
    try:
        df=pd.read_sql(f"SELECT * FROM {table}",engine)
        DataFrame[table] = pd.DataFrame(df)
        print(f"Đã import thành công {table}: {len(df)} dòng")
    except Exception as e:
        print(f"Có lỗ {e}")
# Out:
# Đã import thành công DimSalesTerritory: 11 dòng
# Đã import thành công DimCustomer: 18484 dòng
# Đã import thành công DimDate: 2191 dòng
# Đã import thành công DimGeography: 655 dòng
# Đã import thành công DimProduct: 606 dòng
# Đã import thành công FactInternetSales: 60398 dòng

# %%
for name, df in DataFrame.items():
    globals()[f"df_{name}"]=df
    print(f"Đã tạo thành công bảng {name}")
# Out:
# Đã tạo thành công bảng DimSalesTerritory
# Đã tạo thành công bảng DimCustomer
# Đã tạo thành công bảng DimDate
# Đã tạo thành công bảng DimGeography
# Đã tạo thành công bảng DimProduct
# Đã tạo thành công bảng FactInternetSales

# %%
df_FactInternetSales=pd.DataFrame(df_FactInternetSales)

# %%
df_DimCustomer=pd.DataFrame(df_DimCustomer)

# %%
df_DimDate=pd.DataFrame(df_DimDate)
df_DimGeography=pd.DataFrame(df_DimGeography)
df_DimProduct =pd.DataFrame(df_DimProduct)
df_DimSalesTerritory=pd.DataFrame(df_DimSalesTerritory)

# %%
df_FactInternetSales.head(10)
# Out:
#    ProductKey OrderDateKey  DueDateKey ShipDateKey  CustomerKey  PromotionKey  \
# 0         344   2005-07-22  2005-08-03  2005-07-29        11000             1
# 1         353   2007-07-22  2007-08-03  2007-07-29        11000             2
# 2         485   2007-07-22  2007-08-03  2007-07-29        11000             1
# 3         573   2007-11-04  2007-11-16  2007-11-11        11000             1
# 4         541   2007-11-04  2007-11-16  2007-11-11        11000             1
# 5         530   2007-11-04  2007-11-16  2007-11-11        11000             1
# 6         214   2007-11-04  2007-11-16  2007-11-11        11000             1
# 7         488   2007-11-04  2007-11-16  2007-11-11        11000             1
# 8         350   2005-07-18  2005-07-30  2005-07-25        11001             1
# 9         353   2007-07-20  2007-08-01  2007-07-27        11001             1
#
#    CurrencyKey  SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  ...  \
# 0            6                  9          SO43793                     1  ...
# 1            6                  9          SO51522                     1  ...
# 2            6                  9          SO51522                     2  ...
# 3            6                  9          SO57418                     1  ...
# 4            6                  9          SO57418                     2  ...
# 5            6                  9          SO57418                     3  ...
# 6            6                  9          SO57418                     4  ...
# 7            6                  9          SO57418                     5  ...
# 8            6                  9          SO43767                     1  ...
# 9            6                  9          SO51493                     1  ...
#
#    TaxAmt  Freight  CarrierTrackingNumber  CustomerPONumber   OrderDate  \
# 0  272.00    85.00                   None              None  2005-07-22
# 1  185.60    58.00                   None              None  2007-07-22
# 2    1.76     0.55                   None              None  2007-07-22
# 3  190.73    59.60                   None              None  2007-11-04
# 4    2.32     0.72                   None              None  2007-11-04
# 5    0.40     0.12                   None              None  2007-11-04
# 6    2.80     0.87                   None              None  2007-11-04
# 7    4.32     1.35                   None              None  2007-11-04
# 8  270.00    84.37                   None              None  2005-07-18
# 9  185.60    58.00                   None              None  2007-07-20
#
#       DueDate    ShipDate    Profit   Revenue      COGS
# 0  2005-08-03  2005-07-29  20829.76  47599.86  26770.10
# 1  2007-08-03  2007-07-29   1054.37   2319.99   1265.62
# 2  2007-08-03  2007-07-29     13.76     21.98      8.22
# 3  2007-11-16  2007-11-11    902.13   2384.07   1481.94
# 4  2007-11-16  2007-11-11     18.15     28.99     10.84
# 5  2007-11-16  2007-11-11      3.12      4.99      1.87
# 6  2007-11-16  2007-11-11     21.90     34.99     13.09
# 7  2007-11-16  2007-11-11     12.42     53.99     41.57
# 8  2005-07-30  2005-07-25   1476.90   3374.99   1898.09
# 9  2007-08-01  2007-07-27   1054.37   2319.99   1265.62
#
# [10 rows x 29 columns]

# %%
df_FactInternetSales.drop(columns=["ExtendedAmount","DueDateKey","ShipDateKey"],
                                   inplace=True)

# %%
df_FactInternetSales.head()
# Out:
#    ProductKey OrderDateKey  CustomerKey  PromotionKey  CurrencyKey  \
# 0         344   2005-07-22        11000             1            6
# 1         353   2007-07-22        11000             2            6
# 2         485   2007-07-22        11000             1            6
# 3         573   2007-11-04        11000             1            6
# 4         541   2007-11-04        11000             1            6
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  RevisionNumber  \
# 0                  9          SO43793                     1               1
# 1                  9          SO51522                     1               1
# 2                  9          SO51522                     2               1
# 3                  9          SO57418                     1               1
# 4                  9          SO57418                     2               1
#
#    OrderQuantity  ...  TaxAmt  Freight  CarrierTrackingNumber  \
# 0             14  ...  272.00    85.00                   None
# 1              1  ...  185.60    58.00                   None
# 2              1  ...    1.76     0.55                   None
# 3              1  ...  190.73    59.60                   None
# 4              1  ...    2.32     0.72                   None
#
#    CustomerPONumber   OrderDate     DueDate    ShipDate    Profit   Revenue  \
# 0              None  2005-07-22  2005-08-03  2005-07-29  20829.76  47599.86
# 1              None  2007-07-22  2007-08-03  2007-07-29   1054.37   2319.99
# 2              None  2007-07-22  2007-08-03  2007-07-29     13.76     21.98
# 3              None  2007-11-04  2007-11-16  2007-11-11    902.13   2384.07
# 4              None  2007-11-04  2007-11-16  2007-11-11     18.15     28.99
#
#        COGS
# 0  26770.10
# 1   1265.62
# 2      8.22
# 3   1481.94
# 4     10.84
#
# [5 rows x 26 columns]

# %%
df_DimDate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2191 entries, 0 to 2190
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DateKey               2191 non-null   object
#  1   FullDateAlternateKey  2191 non-null   object
#  2   DayNumberOfWeek       2191 non-null   int64
#  3   EnglishDayNameOfWeek  2191 non-null   object
#  4   SpanishDayNameOfWeek  2191 non-null   object
#  5   FrenchDayNameOfWeek   2191 non-null   object
#  6   DayNumberOfMonth      2191 non-null   int64
#  7   DayNumberOfYear       2191 non-null   int64
#  8   WeekNumberOfYear      2191 non-null   int64
#  9   EnglishMonthName      2191 non-null   object
#  10  SpanishMonthName      2191 non-null   object
#  11  FrenchMonthName       2191 non-null   object
#  12  MonthNumberOfYear     2191 non-null   int64
#  13  CalendarQuarter       2191 non-null   int64
#  14  CalendarYear          2191 non-null   int64
#  15  CalendarSemester      2191 non-null   int64
#  16  FiscalQuarter         2191 non-null   int64
#  17  FiscalYear            2191 non-null   int64
#  18  FiscalSemester        2191 non-null   int64
# dtypes: int64(11), object(8)
# memory usage: 325.4+ KB

# %%
df_DimDate.drop(columns=["SpanishMonthName","FrenchMonthName","SpanishDayNameOfWeek",
                                    "FrenchDayNameOfWeek","DayNumberOfYear","WeekNumberOfYear"],inplace=True)

# %%
df_DimDate['FullDateAlternateKey'] =pd.to_datetime(df_DimDate['FullDateAlternateKey'],"%y-%m-%d")

# %%
df_DimDate['Month_Year']=df_DimDate['FullDateAlternateKey'].dt.strftime("%b-%y")

# %%
df_DimDate.head()
# Out:
#       DateKey FullDateAlternateKey  DayNumberOfWeek EnglishDayNameOfWeek  \
# 0  2005-01-01           2005-01-01                7             Saturday
# 1  2005-01-02           2005-01-02                1               Sunday
# 2  2005-01-03           2005-01-03                2               Monday
# 3  2005-01-04           2005-01-04                3              Tuesday
# 4  2005-01-05           2005-01-05                4            Wednesday
#
#    DayNumberOfMonth EnglishMonthName  MonthNumberOfYear  CalendarQuarter  \
# 0                 1          January                  1                1
# 1                 2          January                  1                1
# 2                 3          January                  1                1
# 3                 4          January                  1                1
# 4                 5          January                  1                1
#
#    CalendarYear  CalendarSemester  FiscalQuarter  FiscalYear  FiscalSemester  \
# 0          2005                 1              3        2005               2
# 1          2005                 1              3        2005               2
# 2          2005                 1              3        2005               2
# 3          2005                 1              3        2005               2
# 4          2005                 1              3        2005               2
#
#   Month_Year
# 0     Jan-05
# 1     Jan-05
# 2     Jan-05
# 3     Jan-05
# 4     Jan-05

# %%
df_Time= pd.merge(df_FactInternetSales,df_DimDate,left_on='OrderDateKey',right_on='DateKey',how='left')

# %%
df_Time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60398 entries, 0 to 60397
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             60398 non-null  int64
#  1   OrderDateKey           60398 non-null  object
#  2   CustomerKey            60398 non-null  int64
#  3   PromotionKey           60398 non-null  int64
#  4   CurrencyKey            60398 non-null  int64
#  5   SalesTerritoryKey      60398 non-null  int64
#  6   SalesOrderNumber       60398 non-null  object
#  7   SalesOrderLineNumber   60398 non-null  int64
#  8   RevisionNumber         60398 non-null  int64
#  9   OrderQuantity          60398 non-null  int64
#  10  UnitPrice              60398 non-null  float64
#  11  UnitPriceDiscountPct   60398 non-null  int64
#  12  DiscountAmount         60398 non-null  int64
#  13  ProductStandardCost    60398 non-null  float64
#  14  TotalProductCost       60398 non-null  float64
#  15  SalesAmount            60398 non-null  float64
#  16  TaxAmt                 60398 non-null  float64
#  17  Freight                60398 non-null  float64
#  18  CarrierTrackingNumber  0 non-null      object
#  19  CustomerPONumber       0 non-null      object
#  20  OrderDate              60398 non-null  object
#  21  DueDate                60398 non-null  object
#  22  ShipDate               60398 non-null  object
#  23  Profit                 60398 non-null  float64
#  24  Revenue                60398 non-null  float64
#  25  COGS                   60398 non-null  float64
#  26  DateKey                60398 non-null  object
#  27  FullDateAlternateKey   60398 non-null  datetime64[ns]
#  28  DayNumberOfWeek        60398 non-null  int64
#  29  EnglishDayNameOfWeek   60398 non-null  object
#  30  DayNumberOfMonth       60398 non-null  int64
#  31  EnglishMonthName       60398 non-null  object
#  32  MonthNumberOfYear      60398 non-null  int64
#  33  CalendarQuarter        60398 non-null  int64
#  34  CalendarYear           60398 non-null  int64
#  35  CalendarSemester       60398 non-null  int64
#  36  FiscalQuarter          60398 non-null  int64
#  37  FiscalYear             60398 non-null  int64
#  38  FiscalSemester         60398 non-null  int64
#  39  Month_Year             60398 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(19), object(11)
# memory usage: 18.4+ MB

# %%
df_Time['OrderQuantity'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_Time.isnull().sum()
# Out:
# ProductKey                   0
# OrderDateKey                 0
# CustomerKey                  0
# PromotionKey                 0
# CurrencyKey                  0
# SalesTerritoryKey            0
# SalesOrderNumber             0
# SalesOrderLineNumber         0
# RevisionNumber               0
# OrderQuantity                0
# UnitPrice                    0
# UnitPriceDiscountPct         0
# DiscountAmount               0
# ProductStandardCost          0
# TotalProductCost             0
# SalesAmount                  0
# TaxAmt                       0
# Freight                      0
# CarrierTrackingNumber    60398
# CustomerPONumber         60398
# OrderDate                    0
# DueDate                      0
# ShipDate                     0
# Profit                       0
# Revenue                      0
# COGS                         0
# DateKey                      0
# FullDateAlternateKey         0
# DayNumberOfWeek              0
# EnglishDayNameOfWeek         0
# DayNumberOfMonth             0
# EnglishMonthName             0
# MonthNumberOfYear            0
# CalendarQuarter              0
# CalendarYear                 0
# CalendarSemester             0
# FiscalQuarter                0
# FiscalYear                   0
# FiscalSemester               0
# Month_Year                   0
# dtype: int64

# %%
df1= df_Time.groupby("CalendarYear")["OrderQuantity"].sum().reset_index()

# %%
df1['OrderQuantity']= df1['OrderQuantity'].apply(lambda x : f"{x/1000:.1f}K")

# %%
df1
# Out:
#    CalendarYear OrderQuantity
# 0          2005         10.4K
# 1          2006         28.4K
# 2          2007        255.7K
# 3          2008        337.4K

# %%
df_Time["Revenue"]= df_Time["OrderQuantity"]*df_Time["UnitPrice"]

# %%
df_Time["COGS"]=df_Time["OrderQuantity"]*df_Time["ProductStandardCost"]

# %%
df_Time["Profit"]=df_Time['Revenue']-df_Time['COGS']

# %%
df_Time.head(10)
# Out:
#    ProductKey OrderDateKey  CustomerKey  PromotionKey  CurrencyKey  \
# 0         344   2005-07-22        11000             1            6
# 1         353   2007-07-22        11000             2            6
# 2         485   2007-07-22        11000             1            6
# 3         573   2007-11-04        11000             1            6
# 4         541   2007-11-04        11000             1            6
# 5         530   2007-11-04        11000             1            6
# 6         214   2007-11-04        11000             1            6
# 7         488   2007-11-04        11000             1            6
# 8         350   2005-07-18        11001             1            6
# 9         353   2007-07-20        11001             1            6
#
#    SalesTerritoryKey SalesOrderNumber  SalesOrderLineNumber  RevisionNumber  \
# 0                  9          SO43793                     1               1
# 1                  9          SO51522                     1               1
# 2                  9          SO51522                     2               1
# 3                  9          SO57418                     1               1
# 4                  9          SO57418                     2               1
# 5                  9          SO57418                     3               1
# 6                  9          SO57418                     4               1
# 7                  9          SO57418                     5               1
# 8                  9          SO43767                     1               1
# 9                  9          SO51493                     1               1
#
#    OrderQuantity  ...  DayNumberOfMonth  EnglishMonthName  MonthNumberOfYear  \
# 0             14  ...                22              July                  7
# 1              1  ...                22              July                  7
# 2              1  ...                22              July                  7
# 3              1  ...                 4          November                 11
# 4              1  ...                 4          November                 11
# 5              1  ...                 4          November                 11
# 6              1  ...                 4          November                 11
# 7              1  ...                 4          November                 11
# 8              1  ...                18              July                  7
# 9              1  ...                20              July                  7
#
#    CalendarQuarter  CalendarYear  CalendarSemester  FiscalQuarter  FiscalYear  \
# 0                3          2005                 2              1        2006
# 1                3          2007                 2              1        2008
# 2                3          2007                 2              1        2008
# 3                4          2007                 2              2        2008
# 4                4          2007                 2              2        2008
# 5                4          2007                 2              2        2008
# 6                4          2007                 2              2        2008
# 7                4          2007                 2              2        2008
# 8                3          2005                 2              1        2006
# 9                3          2007                 2              1        2008
#
#   FiscalSemester Month_Year
# 0              1     Jul-05
# 1              1     Jul-07
# 2              1     Jul-07
# 3              1     Nov-07
# 4              1     Nov-07
# 5              1     Nov-07
# 6              1     Nov-07
# 7              1     Nov-07
# 8              1     Jul-05
# 9              1     Jul-07
#
# [10 rows x 40 columns]

# %%
df2=df_Time.groupby(["CalendarYear","MonthNumberOfYear"]).agg({"COGS":"sum","Revenue":"sum","Profit":"sum"}).reset_index()

# %%
df2
# Out:
#     CalendarYear  MonthNumberOfYear         COGS      Revenue      Profit
# 0           2005                  7   2823378.28   4743642.46  1920264.18
# 1           2005                  8   3062033.05   5121209.54  2059176.49
# 2           2005                  9   3049330.37   5063770.99  2014440.62
# 3           2005                 10   3137425.70   5239925.83  2102500.13
# 4           2005                 11   3428268.13   5737263.57  2308995.44
# 5           2005                 12   4466095.65   7464381.97  2998286.32
# 6           2006                  1   3799009.42   6358230.99  2559221.57
# 7           2006                  2   3494786.42   5821217.14  2326430.72
# 8           2006                  3   4265935.14   7140331.36  2874396.22
# 9           2006                  4   4030681.82   6753887.32  2723205.50
# 10          2006                  5   4582069.05   7676556.96  3094487.91
# 11          2006                  6   4184398.57   7018367.27  2833968.70
# 12          2006                  7   3111591.27   5221662.52  2110071.25
# 13          2006                  8   3405447.39   5729914.29  2324466.90
# 14          2006                  9   2308329.92   3897525.98  1589196.06
# 15          2006                 10   2479657.25   4235194.86  1755537.61
# 16          2006                 11   2064366.07   3479942.08  1415576.01
# 17          2006                 12   3580441.99   6151691.97  2571249.98
# 18          2007                  1   2664943.85   4562516.80  1897572.95
# 19          2007                  2   2913773.66   5032587.29  2118813.63
# 20          2007                  3   2877198.51   4964858.70  2087660.19
# 21          2007                  4   3087906.88   5304878.43  2216971.55
# 22          2007                  5   3240181.22   5626110.54  2385929.32
# 23          2007                  6   3206966.05   5542327.55  2335361.50
# 24          2007                  7   5507123.65   9288353.64  3781229.99
# 25          2007                  8   5092672.11   8744056.73  3651384.62
# 26          2007                  9   6266105.39  10708999.99  4442894.60
# 27          2007                 10   6770580.08  11587932.87  4817352.79
# 28          2007                 11   7348205.85  12586008.54  5237802.69
# 29          2007                 12  10857166.15  18430986.53  7573820.38
# 30          2008                  1   8134556.64  13901555.48  5766998.84
# 31          2008                  2   8980148.95  15327678.27  6347529.32
# 32          2008                  3   8982532.11  15304380.98  6321848.87
# 33          2008                  4   9894635.83  16794232.98  6899597.15
# 34          2008                  5  11691349.92  19944264.19  8252914.27
# 35          2008                  6  11778018.50  20054281.80  8276263.30
# 36          2008                  7    235730.58    532223.01   296492.43

# %%
plt.Figure(figsize=(10,9))
ax = sns.barplot(df2, x= "CalendarYear", y="Profit",color="lightblue", estimator='sum', errorbar=None)
for container in ax.containers:
    ax.bar_label(container, labels=[f"{v.get_height()/1000000:.1f}M" for v in container],padding=3, fontsize=10,fontweight="bold")
plt.xlabel("Year", fontweight="bold")
plt.ylabel("Profit",fontweight="bold")
plt.title("Profit by Year",fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Profit by Year')

# %%
df_melted= df2.melt(id_vars="CalendarYear",value_vars=['Profit', 'Revenue', 'COGS'], var_name="Metric",value_name="Value")

# %%
df_melted
# Out:
#      CalendarYear  Metric        Value
# 0            2005  Profit   1920264.18
# 1            2005  Profit   2059176.49
# 2            2005  Profit   2014440.62
# 3            2005  Profit   2102500.13
# 4            2005  Profit   2308995.44
# ..            ...     ...          ...
# 106          2008    COGS   8982532.11
# 107          2008    COGS   9894635.83
# 108          2008    COGS  11691349.92
# 109          2008    COGS  11778018.50
# 110          2008    COGS    235730.58
#
# [111 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=df_melted,x="CalendarYear",y="Value",hue="Metric",palette="coolwarm",estimator=sum,errorbar=None)
for container in ax.containers:
    ax.bar_label(container,labels=[f'{v.get_height()/1e6:.1f}M' for v in container],padding=3, fontsize=10)

# %%
df3=df_Time.groupby(["Month_Year","CalendarYear","MonthNumberOfYear"]).agg({"COGS":"sum","Revenue":"sum","Profit":"sum"}).reset_index()

# %%
df3
# Out:
#    Month_Year  CalendarYear  MonthNumberOfYear         COGS      Revenue  \
# 0      Apr-06          2006                  4   4030681.82   6753887.32
# 1      Apr-07          2007                  4   3087906.88   5304878.43
# 2      Apr-08          2008                  4   9894635.83  16794232.98
# 3      Aug-05          2005                  8   3062033.05   5121209.54
# 4      Aug-06          2006                  8   3405447.39   5729914.29
# 5      Aug-07          2007                  8   5092672.11   8744056.73
# 6      Dec-05          2005                 12   4466095.65   7464381.97
# 7      Dec-06          2006                 12   3580441.99   6151691.97
# 8      Dec-07          2007                 12  10857166.15  18430986.53
# 9      Feb-06          2006                  2   3494786.42   5821217.14
# 10     Feb-07          2007                  2   2913773.66   5032587.29
# 11     Feb-08          2008                  2   8980148.95  15327678.27
# 12     Jan-06          2006                  1   3799009.42   6358230.99
# 13     Jan-07          2007                  1   2664943.85   4562516.80
# 14     Jan-08          2008                  1   8134556.64  13901555.48
# 15     Jul-05          2005                  7   2823378.28   4743642.46
# 16     Jul-06          2006                  7   3111591.27   5221662.52
# 17     Jul-07          2007                  7   5507123.65   9288353.64
# 18     Jul-08          2008                  7    235730.58    532223.01
# 19     Jun-06          2006                  6   4184398.57   7018367.27
# 20     Jun-07          2007                  6   3206966.05   5542327.55
# 21     Jun-08          2008                  6  11778018.50  20054281.80
# 22     Mar-06          2006                  3   4265935.14   7140331.36
# 23     Mar-07          2007                  3   2877198.51   4964858.70
# 24     Mar-08          2008                  3   8982532.11  15304380.98
# 25     May-06          2006                  5   4582069.05   7676556.96
# 26     May-07          2007                  5   3240181.22   5626110.54
# 27     May-08          2008                  5  11691349.92  19944264.19
# 28     Nov-05          2005                 11   3428268.13   5737263.57
# 29     Nov-06          2006                 11   2064366.07   3479942.08
# 30     Nov-07          2007                 11   7348205.85  12586008.54
# 31     Oct-05          2005                 10   3137425.70   5239925.83
# 32     Oct-06          2006                 10   2479657.25   4235194.86
# 33     Oct-07          2007                 10   6770580.08  11587932.87
# 34     Sep-05          2005                  9   3049330.37   5063770.99
# 35     Sep-06          2006                  9   2308329.92   3897525.98
# 36     Sep-07          2007                  9   6266105.39  10708999.99
#
#         Profit
# 0   2723205.50
# 1   2216971.55
# 2   6899597.15
# 3   2059176.49
# 4   2324466.90
# 5   3651384.62
# 6   2998286.32
# 7   2571249.98
# 8   7573820.38
# 9   2326430.72
# 10  2118813.63
# 11  6347529.32
# 12  2559221.57
# 13  1897572.95
# 14  5766998.84
# 15  1920264.18
# 16  2110071.25
# 17  3781229.99
# 18   296492.43
# 19  2833968.70
# 20  2335361.50
# 21  8276263.30
# 22  2874396.22
# 23  2087660.19
# 24  6321848.87
# 25  3094487.91
# 26  2385929.32
# 27  8252914.27
# 28  2308995.44
# 29  1415576.01
# 30  5237802.69
# 31  2102500.13
# 32  1755537.61
# 33  4817352.79
# 34  2014440.62
# 35  1589196.06
# 36  4442894.60

# %%
plt.Figure(figsize=(20,20))
ax =sns.lineplot(df3,x="MonthNumberOfYear", y="Profit", hue="CalendarYear",color ="purple",linewidth=2,markers='o')
for i, row in df3.iterrows():
    profit_m= row['Profit']/1000000
    ax.annotate(f"{profit_m:.1f}M",
                (row["MonthNumberOfYear"], row["Profit"]), textcoords="offset points",
                xytext=(0,12),
                ha="center",
                fontsize=7,
                fontweight="bold")
plt.xlabel("Month")
plt.ylabel("Profit")
plt.title("Profit by Month")
# Out:
# Text(0.5, 1.0, 'Profit by Month')

# %%
plt.Figure(figsize=(10,9))
ax =sns.barplot(df2,x="MonthNumberOfYear", y="Profit",hue="CalendarYear",palette="coolwarm",linewidth=2)
plt.xlabel("Month-Year")
plt.ylabel("Profit")
plt.title("Profit by Month")
# Out:
# Text(0.5, 1.0, 'Profit by Month')

# %%
df_Time["Weekday/Weekend"]= df_Time["DayNumberOfWeek"].apply(lambda x : "Weekday" if x in range(2,7) else "Weekend")

# %%
df_Time[["Weekday/Weekend","EnglishDayNameOfWeek"]].query('EnglishDayNameOfWeek != "Saturday" and EnglishDayNameOfWeek != "Sunday"')
# Out:
#       Weekday/Weekend EnglishDayNameOfWeek
# 0             Weekday               Friday
# 8             Weekday               Monday
# 9             Weekday               Friday
# 10            Weekday               Friday
# 11            Weekday               Friday
# ...               ...                  ...
# 60393         Weekday               Friday
# 60394         Weekday               Friday
# 60395         Weekday               Monday
# 60396         Weekday             Thursday
# 60397         Weekday              Tuesday
#
# [43344 rows x 2 columns]

# %%
df4=df_Time.groupby(["EnglishDayNameOfWeek","DayNumberOfWeek"]).agg({"COGS":"sum","Revenue":"sum","Profit":"sum"}).reset_index()

# %%
df4['EnglishDayNameOfWeek']=df4['EnglishDayNameOfWeek'].str[:3]

# %%
df4= df4.sort_values("DayNumberOfWeek")

# %%
df4.query('Profit > 18000000 and COGS>25876034')
# Out:
#   EnglishDayNameOfWeek  DayNumberOfWeek         COGS      Revenue       Profit
# 4                  Thu                5  27144921.52  45955381.13  18810459.61
# 0                  Fri                6  26216323.92  44495924.62  18279600.70

# %%
plt.Figure(figsize=(10,9))
ax =sns.barplot(df4, x="EnglishDayNameOfWeek", y="Profit", palette="mako",estimator=sum,errorbar=None)
for container in ax.containers:
    ax.bar_label(container,labels=[f'{v.get_height()/1e6:.1f}M' for v in container],padding=3, fontsize=10)
plt.xlabel("Weekday")
plt.ylabel("Profit")
plt.title("Weekday")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18712\3572019830.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax =sns.barplot(df4, x="EnglishDayNameOfWeek", y="Profit", palette="mako",estimator=sum,errorbar=None)
# Text(0.5, 1.0, 'Weekday')

# %%
import numpy as np
import pandas as pd

# %%
a = 100
b= 200
tong = 0
for i in range(100,200):
    if  i%2 !=0:
        tong += i
tong
# Out:
# 7500

# %%
# Out:
# A: 221
# T: 216
# G: 204
# C: 674

# %%
str="AAAACCCGGT"
mapping = {"A":"T", "T":"A", "G":"C", "C":"G"}
str ="".join(mapping[c] for c in str)
str[::-1]
# Out:
# 'ACCGGGTTTT'
